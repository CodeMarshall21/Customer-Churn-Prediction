# %% [markdown]
# # Importing Modules

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from xgboost.callback import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.metrics import balanced_accuracy_score, roc_auc_score, make_scorer
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# # Using Dataset

# %%
df = pd.read_csv("Dataset\Telco_customer_churn.csv")

# %%
df.head()
# Out:
#    CustomerID  Count  ...  CLTV                   Churn Reason
# 0  3668-QPYBK      1  ...  3239   Competitor made better offer
# 1  9237-HQITU      1  ...  2701                          Moved
# 2  9305-CDSKC      1  ...  5372                          Moved
# 3  7892-POOKP      1  ...  5003                          Moved
# 4  0280-XJGEX      1  ...  5340  Competitor had better devices
#
# [5 rows x 33 columns]

# %% [markdown]
# # Dropping unwanted columns

# %%
df.drop(["Churn Label", "Churn Score", "CLTV", "Churn Reason"], axis=1, inplace=True)
df.head()
# Out:
#    CustomerID  Count        Country  ... Monthly Charges Total Charges  Churn Value
# 0  3668-QPYBK      1  United States  ...           53.85        108.15            1
# 1  9237-HQITU      1  United States  ...           70.70        151.65            1
# 2  9305-CDSKC      1  United States  ...           99.65         820.5            1
# 3  7892-POOKP      1  United States  ...          104.80       3046.05            1
# 4  0280-XJGEX      1  United States  ...          103.70        5036.3            1
#
# [5 rows x 29 columns]

# %%
df["Country"].unique()
# Out:
# <StringArray>
# ['United States']
# Length: 1, dtype: str

# %%
df["Count"].unique()
# Out:
# array([1])

# %%
df["State"].unique()
# Out:
# <StringArray>
# ['California']
# Length: 1, dtype: str

# %%
df["City"].unique()
# Out:
# <StringArray>
# [    'Los Angeles',   'Beverly Hills', 'Huntington Park',         'Lynwood',
#   'Marina Del Rey',       'Inglewood',    'Santa Monica',        'Torrance',
#         'Whittier',        'La Habra',
#  ...
#       'Janesville',      'Litchfield',        'Loyalton',        'Madeline',
#     'Markleeville',         'Milford',         'Calpine',        'Standish',
#         'Tulelake',  'Olympic Valley']
# Length: 1129, dtype: str

# %%
df.drop(["Count", "State", "Country", "CustomerID", "Lat Long"], axis=1, inplace=True)
df.head()
# Out:
#           City  Zip Code   Latitude  ...  Monthly Charges Total Charges Churn Value
# 0  Los Angeles     90003  33.964131  ...            53.85        108.15           1
# 1  Los Angeles     90005  34.059281  ...            70.70        151.65           1
# 2  Los Angeles     90006  34.048013  ...            99.65         820.5           1
# 3  Los Angeles     90010  34.062125  ...           104.80       3046.05           1
# 4  Los Angeles     90015  34.039224  ...           103.70        5036.3           1
#
# [5 rows x 24 columns]

# %% [markdown]
# # Eliminating Whitespaces

# %%
df["City"] = df["City"].replace(' ', '_', regex=True)
df.head()
# Out:
#           City  Zip Code   Latitude  ...  Monthly Charges Total Charges Churn Value
# 0  Los_Angeles     90003  33.964131  ...            53.85        108.15           1
# 1  Los_Angeles     90005  34.059281  ...            70.70        151.65           1
# 2  Los_Angeles     90006  34.048013  ...            99.65         820.5           1
# 3  Los_Angeles     90010  34.062125  ...           104.80       3046.05           1
# 4  Los_Angeles     90015  34.039224  ...           103.70        5036.3           1
#
# [5 rows x 24 columns]

# %%
df.columns = df.columns.str.replace(' ', '_')
df.head()
# Out:
#           City  Zip_Code   Latitude  ...  Monthly_Charges Total_Charges Churn_Value
# 0  Los_Angeles     90003  33.964131  ...            53.85        108.15           1
# 1  Los_Angeles     90005  34.059281  ...            70.70        151.65           1
# 2  Los_Angeles     90006  34.048013  ...            99.65         820.5           1
# 3  Los_Angeles     90010  34.062125  ...           104.80       3046.05           1
# 4  Los_Angeles     90015  34.039224  ...           103.70        5036.3           1
#
# [5 rows x 24 columns]

# %% [markdown]
# # Identifying missing data

# %%
df.dtypes
# Out:
# City                     str
# Zip_Code               int64
# Latitude             float64
# Longitude            float64
# Gender                   str
# Senior_Citizen           str
# Partner                  str
# Dependents               str
# Tenure_Months          int64
# Phone_Service            str
# Multiple_Lines           str
# Internet_Service         str
# Online_Security          str
# Online_Backup            str
# Device_Protection        str
# Tech_Support             str
# Streaming_TV             str
# Streaming_Movies         str
# Contract                 str
# Paperless_Billing        str
# Payment_Method           str
# Monthly_Charges      float64
# Total_Charges            str
# Churn_Value            int64
# dtype: object

# %%
df["Phone_Service"].unique()
# Out:
# <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str

# %%
# df["Total_Charges"] = pd.to_numeric(df["Total_Charges"]) #Unable to parse string " " at position 2234 
# WE NEED TO DEAL WITH THIS LATER

# %% [markdown]
# # Dealing missing data

# %%
len(df.loc[df["Total_Charges"] == " "])
# Out:
# 11

# %%
df.loc[df["Total_Charges"] == " "]
# Out:
#                 City  Zip_Code  ...  Total_Charges  Churn_Value
# 2234  San_Bernardino     92408  ...                           0
# 2438    Independence     93526  ...                           0
# 2568       San_Mateo     94401  ...                           0
# 2667       Cupertino     95014  ...                           0
# 2856        Redcrest     95569  ...                           0
# 4331     Los_Angeles     90029  ...                           0
# 4687        Sun_City     92585  ...                           0
# 5104      Ben_Lomond     95005  ...                           0
# 5719        La_Verne     91750  ...                           0
# 6772            Bell     90201  ...                           0
# 6840      Wilmington     90744  ...                           0
#
# [11 rows x 24 columns]

# %%
df["Total_Charges"] = pd.to_numeric(df["Total_Charges"].replace(' ', 0))

# %%
df.loc[df["Tenure_Months"] == 0]
# Out:
#                 City  Zip_Code  ...  Total_Charges  Churn_Value
# 2234  San_Bernardino     92408  ...            0.0            0
# 2438    Independence     93526  ...            0.0            0
# 2568       San_Mateo     94401  ...            0.0            0
# 2667       Cupertino     95014  ...            0.0            0
# 2856        Redcrest     95569  ...            0.0            0
# 4331     Los_Angeles     90029  ...            0.0            0
# 4687        Sun_City     92585  ...            0.0            0
# 5104      Ben_Lomond     95005  ...            0.0            0
# 5719        La_Verne     91750  ...            0.0            0
# 6772            Bell     90201  ...            0.0            0
# 6840      Wilmington     90744  ...            0.0            0
#
# [11 rows x 24 columns]

# %%
df.replace(' ', '_', regex = True, inplace = True)
# Out:
#               City  Zip_Code  ...  Total_Charges  Churn_Value
# 0      Los_Angeles     90003  ...         108.15            1
# 1      Los_Angeles     90005  ...         151.65            1
# 2      Los_Angeles     90006  ...         820.50            1
# 3      Los_Angeles     90010  ...        3046.05            1
# 4      Los_Angeles     90015  ...        5036.30            1
# ...            ...       ...  ...            ...          ...
# 7038       Landers     92285  ...        1419.40            0
# 7039      Adelanto     92301  ...        1990.50            0
# 7040         Amboy     92304  ...        7362.90            0
# 7041  Angelus_Oaks     92305  ...         346.45            0
# 7042  Apple_Valley     92308  ...        6844.50            0
#
# [7043 rows x 24 columns]

# %% [markdown]
# # Format Data X and y

# %%
X = df.drop("Churn_Value", axis = 1).copy()
X.head()
# Out:
#           City  Zip_Code  ...  Monthly_Charges  Total_Charges
# 0  Los_Angeles     90003  ...            53.85         108.15
# 1  Los_Angeles     90005  ...            70.70         151.65
# 2  Los_Angeles     90006  ...            99.65         820.50
# 3  Los_Angeles     90010  ...           104.80        3046.05
# 4  Los_Angeles     90015  ...           103.70        5036.30
#
# [5 rows x 23 columns]

# %%
y = df["Churn_Value"].copy()
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Churn_Value, dtype: int64

# %% [markdown]
# # One-Hot Encoding

# %%
pd.get_dummies(X, columns = ["Payment_Method"]).head()
# Out:
#           City  ...  Payment_Method_Mailed_check
# 0  Los_Angeles  ...                         True
# 1  Los_Angeles  ...                        False
# 2  Los_Angeles  ...                        False
# 3  Los_Angeles  ...                        False
# 4  Los_Angeles  ...                        False
#
# [5 rows x 26 columns]

# %%
str_cols = X.select_dtypes(include="str").columns
X_encoded = pd.get_dummies(X, columns = str_cols)
X_encoded.head()
# Out:
#    Zip_Code  ...  Payment_Method_Mailed_check
# 0     90003  ...                         True
# 1     90005  ...                        False
# 2     90006  ...                        False
# 3     90010  ...                        False
# 4     90015  ...                        False
#
# [5 rows x 1178 columns]

# %%
# Final check with y
y.unique()
# Out:
# array([1, 0])

# %% [markdown]
# # Train Test Split

# %%
sum(y)/len(y)
# Out:
# 0.2653698707936959

# %%
# usind stratify
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size = 0.2, random_state = 42, stratify = y)

# %%
sum(y_train)/len(y_train)
# Out:
# 0.2653532126375577

# %%
sum(y_test)/len(y_test)
# Out:
# 0.2654364797728886

# %% [markdown]
# # Build a preliminary XGBoost Model

# %%
xgb_model = xgb.XGBClassifier(objective="binary:logistic", early_stopping_rounds=10, eval_metric="aucpr", seed=42)
xgb_model.fit(X_train, y_train, 
              verbose=True,
              eval_set=[(X_test, y_test)])
# Out:
# [0]	validation_0-aucpr:0.64661
# [1]	validation_0-aucpr:0.65831
# [2]	validation_0-aucpr:0.65094
# [3]	validation_0-aucpr:0.65846
# [4]	validation_0-aucpr:0.66019
# [5]	validation_0-aucpr:0.65974
# [6]	validation_0-aucpr:0.65614
# [7]	validation_0-aucpr:0.65528
# [8]	validation_0-aucpr:0.65656
# [9]	validation_0-aucpr:0.65720
# [10]	validation_0-aucpr:0.64919
# [11]	validation_0-aucpr:0.65198
# [12]	validation_0-aucpr:0.65018
# [13]	validation_0-aucpr:0.65003
# [14]	validation_0-aucpr:0.64853
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric='aucpr', feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
# ...

# %% [markdown]
# # Plot confusion matrix

# %%
y_pred = xgb_model.predict(X_test)
ConfusionMatrixDisplay.from_predictions(y_test, y_pred, display_labels=["Not Churned", "Churned"])

# %% [markdown]
# # Optimizing parameters with cross validation (GridSearch)

# %%
# ## NOTE: When data are imbalanced, the XGBoost manual says ...
# ## If you care only about the overall performance metric (AUC) of your prediction
# Balance the positive and negative weights via scale_pos_weight
# Use AUC for evaluation

#Round 1
param_grid ={
    'max_depth':[3, 4, 5],
    'learning_rate': [0.1, 0.01, 0.05],
    'reg_lambda': [0, 1, 10],
    'gamma': [0, 0.25, 1],
    'scale_pos_weight': [1, 3, 5]   #scale_pos_weight [default=1] 
                                    # Control the balance of positive and negative weights, 
                                    # useful for unbalanced classes. 
                                    # A typical value to consider: sum(negative instances) / sum(positive instances)
}

# %%
#Round 2
param_grid ={
    'max_depth':[4],
    'learning_rate': [0.1, 0.5, 1],
    'reg_lambda': [10, 20, 100],
    'gamma': [0.25],
    'scale_pos_weight': [3]    
}

# %%
from sklearn.model_selection import GridSearchCV

## NOTE: To speed up cross validiation, and to further prevent overfitting.
## We are only using a random subset of the data (90%) and are only
## using a random subset of the features (columns) (50%) per tree.
optimal_param = GridSearchCV(estimator=xgb.XGBClassifier(objective="binary:logistic",
                                                         early_stopping_rounds=10, 
                                                         eval_metric="aucpr", 
                                                         sub_sample=0.9,
                                                         colsample_bytree=0.5,
                                                         seed=42),
                            param_grid=param_grid,
                            verbose=2,
                            cv = 3,
                            n_jobs=10,
                            scoring='roc_auc_score')

# %%
optimal_param.fit(X_train, 
                  y_train,
                  verbose=True,
                eval_set=[(X_test, y_test)])
